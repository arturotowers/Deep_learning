# %% [markdown]
# ### Denoising AutoEncoder

# %% [markdown]
# Importamos las librerías necesarias.

# %%
import wandb
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import os
import matplotlib.pyplot as plt
import glob

print(tf.__version__)
# Out:
# 2.18.0

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: pablo-blanco (arturo-torres-iteso) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# Vamos a cargar las imágenes ya preprocesadas que están almacenadas como .npy.

# %%
train_data_path = "/content/Deep_learning/Proyecto 1 - DAE + VAE/processed_dataset/train/*/*.npy"
val_data_path   = "/content/Deep_learning/Proyecto 1 - DAE + VAE/processed_dataset/val/*/*.npy"
test_data_path  = "/content/Deep_learning/Proyecto 1 - DAE + VAE/processed_dataset/test/*/*.npy"

# %%
def load_image(file_path):
    """
    Carga el archivo .npy desde la ruta dada y lo retorna como un np.array de tipo float32.
    """
    # file_path es un tensor tipo tf.string, convertimos a str en Python
    file_path = file_path.numpy().decode("utf-8")
    image = np.load(file_path).astype(np.float32)  # shape (256,256,3) según tu preprocesado
    return image

# %%
def load_and_preprocess(file_path):
    """
    Carga la imagen .npy, la deja en [0,1] (ya normalizada),
    y agrega ruido gaussiano. Devuelve (noisy_image, clean_image).
    """
    # tf.py_function permite usar funciones de NumPy dentro de un pipeline de tf.data
    image = tf.py_function(func=load_image, inp=[file_path], Tout=tf.float32)
    image.set_shape([256, 256, 3])  # Ajusta si tu imagen tiene otro tamaño

    clean_image = image  # La imagen limpia (original)

    # Agregar ruido gaussiano
    noise_std = 0.3  # Desviación estándar del ruido
    noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=noise_std, dtype=tf.float32)
    noisy_image = tf.clip_by_value(image + noise, 0.0, 1.0)

    return noisy_image, clean_image

# %%
train_file_paths = glob.glob(train_data_path, recursive=True)
val_file_paths   = glob.glob(val_data_path,   recursive=True)
test_file_paths  = glob.glob(test_data_path,  recursive=True)

print("Total imágenes (train):", len(train_file_paths))
print("Total imágenes (val):",   len(val_file_paths))
print("Total imágenes (test):",  len(test_file_paths))
# Out:
# Total imágenes (train): 90
# Total imágenes (val): 20
# Total imágenes (test): 20

# %%
# Convertir las rutas en tf.data.Dataset
train_dataset = tf.data.Dataset.from_tensor_slices(train_file_paths)
val_dataset   = tf.data.Dataset.from_tensor_slices(val_file_paths)
test_dataset  = tf.data.Dataset.from_tensor_slices(test_file_paths)

# %%
# Mapear la función de carga y preprocesado (aplica ruido a cada imagen)
train_dataset = train_dataset.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset   = val_dataset.map(load_and_preprocess,   num_parallel_calls=tf.data.AUTOTUNE)
test_dataset  = test_dataset.map(load_and_preprocess,  num_parallel_calls=tf.data.AUTOTUNE)

# %%
# Definir batch y prefetch
batch_size = 16
train_dataset = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_dataset   = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_dataset  = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
noisy_batch, clean_batch = next(iter(train_dataset))

print("Shape de noisy_batch:", noisy_batch.shape)
print("Shape de clean_batch:", clean_batch.shape)

# Mostrar 3 ejemplos
plt.figure(figsize=(12, 4))
for i in range(3):
    plt.subplot(2, 3, i+1)
    plt.imshow(clean_batch[i].numpy())
    plt.title("Limpia")
    plt.axis("off")

    plt.subplot(2, 3, i+4)
    plt.imshow(noisy_batch[i].numpy())
    plt.title("Con Ruido")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Shape de noisy_batch: (16, 256, 256, 3)
# Shape de clean_batch: (16, 256, 256, 3)

# %% [markdown]
# Aquí ya le agregamos ruído a nuestras imágenes, que están listas para meterse a nuestro modelo.

# %%
def create_dae_model(input_shape=(256,256,3)):
    """
    Crea y devuelve un modelo Keras para Denoising Autoencoder (DAE).

    Parámetros:
    - input_shape: tupla con (altura, ancho, canales).

    Retorna:
    - model: objeto keras.Model listo para compilar.
    """
    # ENCODER
    inputs = keras.Input(shape=input_shape, name="input_image")

    # Capa Conv 1
    x = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D((2,2), padding='same')(x)  # reduce a la mitad altura y ancho

    # Capa Conv 2
    x = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2), padding='same')(x)

    # Capa Conv 3 (Latent Space)
    x = layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(x)
    # En este punto x es la representación "latente" comprimida

    # DECODER
    x = layers.UpSampling2D((2,2))(x)  # aumenta tamaño de la imagen
    x = layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(x)

    x = layers.UpSampling2D((2,2))(x)
    x = layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(x)

    # Capa de salida
    outputs = layers.Conv2D(filters=3, kernel_size=(3,3), activation='sigmoid', padding='same', name="output_image")(x)

    # Construimos el modelo
    model = keras.Model(inputs, outputs, name="DenoisingAutoencoder")
    return model

# %%
# Creamos el modelo
model = create_dae_model(input_shape=(256,256,3))

# %%
# Compilamos con optimizador Adam y pérdida MSE (para reconstrucción de imagen)
model.compile(optimizer='adam', loss='mse')

# Mostramos la arquitectura
model.summary()
# Out:
# Model: "DenoisingAutoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)             │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 256, 256, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 128, 128, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 128, 128, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 128, 128, 64)        │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 256, 256, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 256, 256, 32)        │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_image (Conv2D)                │ (None, 256, 256, 3)         │             867 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 186,371 (728.01 KB)
#  Trainable params: 186,371 (728.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define your training loop and integrate wandb logging
def train_model(model, train_dataset, val_dataset, epochs=200):
  with wandb.init(project="VAE + DAE", entity="arturo-torres-iteso",name="DAE_train5", config={"epochs": epochs, "batch_size": batch_size}):
    config = wandb.config
    for epoch in range(config.epochs):
      for batch_idx, (noisy_batch, clean_batch) in enumerate(train_dataset):
        loss = model.train_on_batch(noisy_batch, clean_batch)
        # Log training loss to wandb
        wandb.log({"train_loss": loss, "epoch": epoch, "batch": batch_idx})

      # Evaluate on validation dataset
      val_loss = model.evaluate(val_dataset, verbose=0)
      # Log validation loss to wandb
      wandb.log({"val_loss": val_loss, "epoch": epoch})

      print(f"Epoch {epoch+1}/{config.epochs}, Loss: {loss:.4f}, Val Loss: {val_loss:.4f}")


# Call the training function
train_model(model, train_dataset, val_dataset, epochs=30)
# Out:
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250321_002147-b5ohopm7</code>
# Syncing run <strong><a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/b5ohopm7' target="_blank">DAE_train5</a></strong> to <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE</a>
#  View run at <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/b5ohopm7' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/b5ohopm7</a>
# Epoch 1/30, Loss: 0.0057, Val Loss: 0.0065
# Epoch 2/30, Loss: 0.0057, Val Loss: 0.0066
# Epoch 3/30, Loss: 0.0057, Val Loss: 0.0068
# Epoch 4/30, Loss: 0.0059, Val Loss: 0.0066
# Epoch 5/30, Loss: 0.0058, Val Loss: 0.0063
# Epoch 6/30, Loss: 0.0057, Val Loss: 0.0062
# Epoch 7/30, Loss: 0.0058, Val Loss: 0.0074
# Epoch 8/30, Loss: 0.0061, Val Loss: 0.0067
# Epoch 9/30, Loss: 0.0056, Val Loss: 0.0062
# Epoch 10/30, Loss: 0.0054, Val Loss: 0.0063
# Epoch 11/30, Loss: 0.0054, Val Loss: 0.0059
# Epoch 12/30, Loss: 0.0051, Val Loss: 0.0057
# Epoch 13/30, Loss: 0.0050, Val Loss: 0.0056
# Epoch 14/30, Loss: 0.0050, Val Loss: 0.0057
# Epoch 15/30, Loss: 0.0051, Val Loss: 0.0064
# Epoch 16/30, Loss: 0.0055, Val Loss: 0.0055
# Epoch 17/30, Loss: 0.0050, Val Loss: 0.0058
# Epoch 18/30, Loss: 0.0050, Val Loss: 0.0055
# Epoch 19/30, Loss: 0.0049, Val Loss: 0.0058
# Epoch 20/30, Loss: 0.0051, Val Loss: 0.0053
# Epoch 21/30, Loss: 0.0048, Val Loss: 0.0056
# Epoch 22/30, Loss: 0.0048, Val Loss: 0.0052
# Epoch 23/30, Loss: 0.0047, Val Loss: 0.0055
# Epoch 24/30, Loss: 0.0049, Val Loss: 0.0052
# Epoch 25/30, Loss: 0.0048, Val Loss: 0.0065
# Epoch 26/30, Loss: 0.0050, Val Loss: 0.0054
# Epoch 27/30, Loss: 0.0047, Val Loss: 0.0051
# Epoch 28/30, Loss: 0.0045, Val Loss: 0.0049
# Epoch 29/30, Loss: 0.0044, Val Loss: 0.0049
# Epoch 30/30, Loss: 0.0044, Val Loss: 0.0050
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch</td><td>▁▄██▁▇█▁█▁▇█▁▄▇▇▂▄█▂▁▅▅▂▅▄▅▁▄▇▂▄█▁█▂▅▁▂█</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>▄█▃▆█▅█▄▆▇▆▂▄▆▄▅▆▄▄▅▂▅▄▄▄▂▃▅▂▂▅▅▆▂▄▁▄▃▁▄</td></tr><tr><td>val_loss</td><td>▅▆▆▆▅▅█▆▅▅▄▃▃▃▅▃▃▃▃▂▃▂▃▂▅▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch</td><td>5</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>train_loss</td><td>0.00441</td></tr><tr><td>val_loss</td><td>0.00504</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DAE_train5</strong> at: <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/b5ohopm7' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/b5ohopm7</a><br> View project at: <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250321_002147-b5ohopm7/logs</code>

# %%
# Obtener un batch de imágenes de prueba
noisy_batch, clean_batch = next(iter(test_dataset))

# Predecir las imágenes denoised usando el modelo entrenado
denoised_batch = model.predict(noisy_batch)

# Mostrar las imágenes originales, ruidosas y denoised
plt.figure(figsize=(12, 4))
for i in range(3):
    plt.subplot(1, 3, 1)
    plt.imshow(clean_batch[-i].numpy())
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(noisy_batch[-i].numpy())
    plt.title("Noisy Image")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(denoised_batch[-i])
    plt.title("Denoised Image")
    plt.axis("off")

    plt.tight_layout()
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
# Guardar en formato .h5
model.save('./DeepLearning/Proyecto 1 - DAE + VAE/vae_dae_model.h5')

# Subir a W&B
artifact = wandb.Artifact('vae_dae_model', type='model')
artifact.add_file('./DeepLearning/Proyecto 1 - DAE + VAE/vae_dae_model.h5')

with wandb.init(project="VAE_DAE_Project", entity="arturo-torres-iteso"):
    wandb.log_artifact(artifact)
    print("Modelo subido exitosamente a WandB!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250321_010132-1d84iccy</code>
# Syncing run <strong><a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project/runs/1d84iccy' target="_blank">stilted-universe-2</a></strong> to <a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project</a>
#  View run at <a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project/runs/1d84iccy' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project/runs/1d84iccy</a>
# Modelo subido exitosamente a WandB!
#  View run <strong style="color:#cdcd00">stilted-universe-2</strong> at: <a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project/runs/1d84iccy' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project/runs/1d84iccy</a><br> View project at: <a href='https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE_DAE_Project</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250321_010132-1d84iccy/logs</code>
