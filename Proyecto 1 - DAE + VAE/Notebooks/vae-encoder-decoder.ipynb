# %%
import os, glob, random
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import wandb
from wandb.integration.keras import WandbCallback
import gc

# Decorador para que Hugging Face/Keras reconozcan la función
@tf.keras.utils.register_keras_serializable()
def calc_mvd(real_images, gen_images):
    """
    Calcula la distancia entre medias y desviaciones estándar (Mean-Variance Distance)
    entre un conjunto de imágenes reales y otro de imágenes generadas.
    """
    real_flat = real_images.reshape(real_images.shape[0], -1)
    gen_flat = gen_images.reshape(gen_images.shape[0], -1)
    mean_real = np.mean(real_flat, axis=0)
    std_real = np.std(real_flat, axis=0)
    mean_gen = np.mean(gen_flat, axis=0)
    std_gen = np.std(gen_flat, axis=0)
    mean_distance = np.linalg.norm(mean_real - mean_gen)
    std_distance = np.linalg.norm(std_real - std_gen)
    return mean_distance + std_distance

# Callback para loguear MVD al final de cada época
class MVDEpochCallback(tf.keras.callbacks.Callback):
    def __init__(self, real_data, decoder, latent_dim, label_prefix="Train"):
        super().__init__()
        self.real_data = real_data
        self.decoder = decoder
        self.latent_dim = latent_dim
        self.label_prefix = label_prefix

    def on_epoch_end(self, epoch, logs=None):
        # Generar muestras aleatorias en el espacio latente
        z_samples = np.random.normal(size=(len(self.real_data), self.latent_dim))
        gen_images = self.decoder.predict(z_samples)
        # Calcular MVD entre las imágenes reales y generadas
        mvd_value = calc_mvd(self.real_data, gen_images)
        # Loguear en W&B
        wandb.log({f"MVD_{self.label_prefix}": mvd_value, "epoch": epoch})

# %%
# Rutas base
base_path = "/content/input/3-botellas-y-relojes/Proyecto 1 - DAE + VAE/processed_dataset"
train_path = os.path.join(base_path, "train")
val_path   = os.path.join(base_path, "val")
test_path  = os.path.join(base_path, "test")

# Obtener las rutas de las imágenes para cada categoría
train_paths_botellas = glob.glob(os.path.join(train_path + "/botella_de_vidrio/*.npy"))
train_paths_relojes  = glob.glob(train_path + "/reloj_de_pared_circular_clasico/*.npy")

val_paths_botellas   = glob.glob(val_path + "/botella_de_vidrio/*.npy")
val_paths_relojes    = glob.glob(val_path + "/reloj_de_pared_circular_clasico/*.npy")

test_paths_botellas  = glob.glob(test_path + "/botella_de_vidrio/*.npy")
test_paths_relojes   = glob.glob(test_path + "/reloj_de_pared_circular_clasico/*.npy")

# Cargar las imágenes para cada categoría
X_train_botellas = np.array([np.load(p) for p in train_paths_botellas])
X_train_relojes  = np.array([np.load(p) for p in train_paths_relojes])

X_val_botellas   = np.array([np.load(p) for p in val_paths_botellas])
X_val_relojes    = np.array([np.load(p) for p in val_paths_relojes])

X_test_botellas  = np.array([np.load(p) for p in test_paths_botellas])
X_test_relojes   = np.array([np.load(p) for p in test_paths_relojes])

# %%
print("Botellas - Train:", X_train_botellas.shape, "Val:", X_val_botellas.shape, "Test:", X_test_botellas.shape)
print("Relojes - Train:", X_train_relojes.shape, "Val:", X_val_relojes.shape, "Test:", X_test_relojes.shape)
# Out:
# Botellas - Train: (45, 256, 256, 3) Val: (10, 256, 256, 3) Test: (10, 256, 256, 3)
# Relojes - Train: (45, 256, 256, 3) Val: (10, 256, 256, 3) Test: (10, 256, 256, 3)

# %%
# Semilla para reproducibilidad
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)

# Definir tamaño de imagen
IMG_SIZE = 256  # Ajusta según tu dataset

# %%
from tensorflow.keras import layers, Model, Input
import tensorflow.keras.backend as K

class VAE(Model):
    def __init__(self, encoder, decoder, img_size=IMG_SIZE, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.img_size = img_size
        self.loss_tracker = tf.keras.metrics.Mean(name="loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def vae_loss(self, y_true, y_pred, z_mean, z_log_var):
        reconstruction_loss = tf.keras.losses.mse(K.flatten(y_true), K.flatten(y_pred))
        reconstruction_loss *= self.img_size * self.img_size * 3
        kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_loss = -0.5 * tf.reduce_mean(kl_loss)
        return reconstruction_loss + kl_loss

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            loss = self.vae_loss(data, reconstruction, z_mean, z_log_var)

        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        self.loss_tracker.update_state(loss)

        # Aquí, para no sobreescribir kl_loss, podrías calcularlo aparte si lo quisieras exacto.
        # Pero en este ejemplo, se actualiza la reconstrucción y KL por separado de forma aproximada.
        # Lo importante es que en logs se vea la métrica final.
        recon_loss_value = reconstruction_loss = tf.keras.losses.mse(
            K.flatten(data), K.flatten(reconstruction)
        ) * (self.img_size * self.img_size * 3)
        kl_value = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_value = -0.5 * tf.reduce_mean(kl_value)

        self.reconstruction_loss_tracker.update_state(recon_loss_value)
        self.kl_loss_tracker.update_state(kl_value)

        return {
            "loss": self.loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def call(self, inputs):
        z = self.encoder(inputs)[2]
        reconstructed = self.decoder(z)
        return reconstructed

def build_vae(latent_dim, img_size=IMG_SIZE):
    # --- Encoder ---
    encoder_inputs = Input(shape=(img_size, img_size, 3))
    x = layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')(encoder_inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1024, activation='relu')(x)
    z_mean = layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

    def sampling(args):
        z_mean, z_log_var = args
        epsilon = tf.random.normal(shape=tf.shape(z_mean), seed=42)
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
    encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

    # --- Decoder ---
    latent_inputs = Input(shape=(latent_dim,))
    x = layers.Dense((img_size // 16) * (img_size // 16) * 256, activation='relu')(latent_inputs)
    x = layers.Reshape((img_size // 16, img_size // 16, 256))(x)
    x = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(64, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    decoder_outputs = layers.Conv2D(3, 3, activation='sigmoid', padding='same')(x)

    decoder = Model(latent_inputs, decoder_outputs, name="decoder")
    vae = VAE(encoder, decoder, img_size=img_size)
    return vae, encoder, decoder

# %%
# Instanciar y compilar los VAEs para cada clase
LATENT_DIM = 256

# VAE para Botellas
vae_bottle, encoder_bottle, decoder_bottle = build_vae(LATENT_DIM, img_size=IMG_SIZE)
optimizer_bottle = tf.keras.optimizers.Adam(learning_rate=1e-3)
vae_bottle.compile(optimizer=optimizer_bottle, loss=tf.keras.losses.mse)

# VAE para Relojes
vae_clock, encoder_clock, decoder_clock = build_vae(LATENT_DIM, img_size=IMG_SIZE)
optimizer_clock = tf.keras.optimizers.Adam(learning_rate=1e-4)
vae_clock.compile(optimizer=optimizer_clock, loss=tf.keras.losses.mse)

vae_bottle.summary()
vae_clock.summary()
# Out:
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ encoder (Functional)                 │ [(None, 256), (None, 256),  │      68,025,024 │
# │                                      │ (None, 256)]                │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Functional)                 │ (None, 256, 256, 3)         │      17,822,915 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 85,847,939 (327.48 MB)
#  Trainable params: 85,846,019 (327.48 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Model: "vae_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ encoder (Functional)                 │ [(None, 256), (None, 256),  │      68,025,024 │
# │                                      │ (None, 256)]                │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Functional)                 │ (None, 256, 256, 3)         │      17,822,915 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 85,847,939 (327.48 MB)
#  Trainable params: 85,846,019 (327.48 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
wandb.login(key="84acb992804885251a1080b55a34890b5cec77eb")
# Login a wandb
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: diegomercadoc (diegomercadoc-iteso). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# Definir ruta donde se guardarán los modelos
models_path = "/content/input/3-botellas-y-relojes/Proyecto 1 - DAE + VAE/(2)_Data"
os.makedirs(models_path, exist_ok=True)

# %%
import os
import gc
import wandb
import tensorflow as tf

# Entrenamiento VAE Botellas
run_bottle = wandb.init(entity="arturo-torres-iteso", project="VAE + DAE", name="VAE_bottles_Arturo", reinit=True, settings=wandb.Settings(init_timeout=120))

history_bottle = vae_bottle.fit(
    X_train_botellas,
    X_train_botellas,
    epochs=300,
    batch_size=4,
    validation_data=(X_val_botellas, X_val_botellas),
    callbacks=[
        WandbCallback(save_model=False),
        MVDEpochCallback(X_train_botellas, decoder_bottle, LATENT_DIM, label_prefix="Bottles")
    ]
)

# Definir rutas completas para guardar el encoder y decoder de botellas
models_path = "/content/working/"  # Ajusta esta ruta según tu configuración
encoder_save_path_bottle = os.path.join(models_path, "encoder_bottle_Arturo.keras")
decoder_save_path_bottle = os.path.join(models_path, "decoder_bottle_Arturo.keras")

# Guardar el encoder y el decoder por separado
vae_bottle.encoder.save(encoder_save_path_bottle)
vae_bottle.decoder.save(decoder_save_path_bottle)

# Subir los archivos a wandb
wandb.save(encoder_save_path_bottle)
wandb.save(decoder_save_path_bottle)

wandb.finish()

# Liberar memoria
tf.keras.backend.clear_session()
gc.collect()

# Entrenamiento VAE Relojes
run_clock = wandb.init(project="VAE + DAE", name="VAE_Clock_Arturo", reinit=True)

history_clock = vae_clock.fit(
    X_train_relojes,
    X_train_relojes,
    epochs=450,
    batch_size=4,
    validation_data=(X_val_relojes, X_val_relojes),
    callbacks=[
        WandbCallback(save_model=False),
        MVDEpochCallback(X_train_relojes, decoder_clock, LATENT_DIM, label_prefix="Clocks")
    ]
)

# Definir rutas completas para guardar el encoder y decoder de relojes
encoder_save_path_clock = os.path.join(models_path, "encoder_clock_Arturo.keras")
decoder_save_path_clock = os.path.join(models_path, "decoder_clock_Arturo.keras")

# Guardar el encoder y el decoder por separado
vae_clock.encoder.save(encoder_save_path_clock)
vae_clock.decoder.save(decoder_save_path_clock)

# Subir los archivos a wandb
wandb.save(encoder_save_path_clock)
wandb.save(decoder_save_path_clock)

wandb.finish()

# Liberar memoria
tf.keras.backend.clear_session()
gc.collect()
# Out:
# wandb: Currently logged in as: diegomercadoc (arturo-torres-iteso). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250322_022515-lk8a3yuk</code>
# Syncing run <strong><a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/lk8a3yuk' target="_blank">VAE_bottles_Arturo</a></strong> to <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE</a>
#  View run at <a href='https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/lk8a3yuk' target="_blank">https://wandb.ai/arturo-torres-iteso/VAE%20%2B%20DAE/runs/lk8a3yuk</a>
# wandb: WARNING WandbCallback is deprecated and will be removed in a future release. Please use the WandbMetricsLogger, WandbModelCheckpoint, and WandbEvalCallback callbacks instead. See https://docs.wandb.ai/guides/integrations/keras for more information.
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 682ms/stepep - kl_loss: 2997719.5000 - loss: 3024259.0000 - reconstruction_loss: 26539.4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 844ms/step - kl_loss: 2948713.2500 - loss: 2974762.7500 - reconstruction_loss: 26049.3438 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 0.1091 - loss: 14994.5234 - reconstruction_loss: 14994.415
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 0.1119 - loss: 14954.5391 - reconstruction_loss: 14954.4277 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 2.6060 - loss: 14310.7764 - reconstruction_loss: 14308.170
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 2.8508 - loss: 14503.6719 - reconstruction_loss: 14500.8223 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3206 - loss: 12195.9082 - reconstruction_loss: 12191.585
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.4596 - loss: 11940.3223 - reconstruction_loss: 11935.8623 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9949 - loss: 9275.5674 - reconstruction_loss: 9270.572
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9640 - loss: 9247.3730 - reconstruction_loss: 9242.4092 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.4928 - loss: 10189.1904 - reconstruction_loss: 10183.698
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 5.5735 - loss: 10397.4062 - reconstruction_loss: 10391.8330 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 11.9341 - loss: 10004.6445 - reconstruction_loss: 9992.710
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 12.4461 - loss: 10201.6162 - reconstruction_loss: 10189.1699 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.5893 - loss: 9996.0156 - reconstruction_loss: 9989.425
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.9638 - loss: 10032.4932 - reconstruction_loss: 10025.5283 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.8408 - loss: 9311.4131 - reconstruction_loss: 9305.572
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.9808 - loss: 9227.2998 - reconstruction_loss: 9221.3193 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2791 - loss: 9200.8975 - reconstruction_loss: 9197.618
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6529 - loss: 9153.3232 - reconstruction_loss: 9149.6699 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.1169 - loss: 8484.1309 - reconstruction_loss: 8481.013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4563 - loss: 8489.5098 - reconstruction_loss: 8486.0537 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6260 - loss: 8244.6289 - reconstruction_loss: 8241.002
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.6153 - loss: 8247.8379 - reconstruction_loss: 8244.2227 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6762 - loss: 7842.8340 - reconstruction_loss: 7839.157
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.7120 - loss: 7898.7520 - reconstruction_loss: 7895.0400 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 9.1667 - loss: 8540.4297 - reconstruction_loss: 8531.262
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - kl_loss: 8.9524 - loss: 8524.8066 - reconstruction_loss: 8515.8535 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.6886 - loss: 7934.6279 - reconstruction_loss: 7927.939
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 6.7320 - loss: 7921.9609 - reconstruction_loss: 7915.2295 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.9123 - loss: 7500.6396 - reconstruction_loss: 7494.727
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.7919 - loss: 7535.3608 - reconstruction_loss: 7529.5688 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.3238 - loss: 6963.0127 - reconstruction_loss: 6957.689
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.2385 - loss: 7037.0049 - reconstruction_loss: 7031.7666 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.6463 - loss: 6790.9834 - reconstruction_loss: 6785.337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - kl_loss: 5.6056 - loss: 6845.6924 - reconstruction_loss: 6840.0869 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.1324 - loss: 6738.6963 - reconstruction_loss: 6732.564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.8928 - loss: 6827.1582 - reconstruction_loss: 6821.2656 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8441 - loss: 6576.0664 - reconstruction_loss: 6571.222
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.8219 - loss: 6598.3271 - reconstruction_loss: 6593.5059 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9037 - loss: 6357.1924 - reconstruction_loss: 6352.288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6853 - loss: 6334.9814 - reconstruction_loss: 6330.2959 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.3380 - loss: 4931.1284 - reconstruction_loss: 4927.791
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.2943 - loss: 4934.5112 - reconstruction_loss: 4931.2173 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5892 - loss: 4755.9136 - reconstruction_loss: 4752.324
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6235 - loss: 4758.6685 - reconstruction_loss: 4755.0449 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.6948 - loss: 5214.3838 - reconstruction_loss: 5208.688
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.6695 - loss: 5203.0894 - reconstruction_loss: 5197.4189 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.4387 - loss: 4861.4258 - reconstruction_loss: 4855.987
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.2906 - loss: 4855.7300 - reconstruction_loss: 4850.4395 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5873 - loss: 5314.6621 - reconstruction_loss: 5310.074
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.5551 - loss: 5169.8218 - reconstruction_loss: 5165.2666 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.8849 - loss: 5168.2817 - reconstruction_loss: 5162.397
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.7552 - loss: 5140.4404 - reconstruction_loss: 5134.6851 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.3484 - loss: 4854.6631 - reconstruction_loss: 4848.314
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - kl_loss: 6.1383 - loss: 4821.3491 - reconstruction_loss: 4815.2109 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9498 - loss: 4197.1860 - reconstruction_loss: 4192.236
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.8210 - loss: 4183.0767 - reconstruction_loss: 4178.2554 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5201 - loss: 3962.0205 - reconstruction_loss: 3957.500
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.3983 - loss: 4029.8374 - reconstruction_loss: 4025.4392 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.4929 - loss: 3961.8767 - reconstruction_loss: 3957.383
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.3800 - loss: 4010.0645 - reconstruction_loss: 4005.6843 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.1536 - loss: 3911.0459 - reconstruction_loss: 3906.891
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.2797 - loss: 3992.5625 - reconstruction_loss: 3988.2825 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.7227 - loss: 3667.6433 - reconstruction_loss: 3663.920
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - kl_loss: 3.8455 - loss: 3716.0657 - reconstruction_loss: 3712.2200 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5700 - loss: 3488.7688 - reconstruction_loss: 3485.198
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.5392 - loss: 3514.6423 - reconstruction_loss: 3511.1030 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5846 - loss: 3279.7646 - reconstruction_loss: 3276.179
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.5817 - loss: 3292.4434 - reconstruction_loss: 3288.8616 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6124 - loss: 3190.8650 - reconstruction_loss: 3187.252
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6012 - loss: 3213.0925 - reconstruction_loss: 3209.4912 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5398 - loss: 3042.2329 - reconstruction_loss: 3038.693
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.5025 - loss: 3055.7732 - reconstruction_loss: 3052.2708 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6949 - loss: 3098.7471 - reconstruction_loss: 3095.052
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6890 - loss: 3115.7788 - reconstruction_loss: 3112.0898 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5802 - loss: 3073.6597 - reconstruction_loss: 3070.079
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.5621 - loss: 3076.7507 - reconstruction_loss: 3073.1885 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4382 - loss: 3012.9028 - reconstruction_loss: 3009.464
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4218 - loss: 3073.9651 - reconstruction_loss: 3070.5432 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5137 - loss: 2909.6858 - reconstruction_loss: 2906.171
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4640 - loss: 2938.3320 - reconstruction_loss: 2934.8679 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.6962 - loss: 3785.0728 - reconstruction_loss: 3780.376
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.7360 - loss: 3825.8198 - reconstruction_loss: 3821.0833 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.7081 - loss: 5326.1768 - reconstruction_loss: 5320.468
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 6.8727 - loss: 5489.3726 - reconstruction_loss: 5482.4995 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 9.4328 - loss: 6352.6899 - reconstruction_loss: 6343.257
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 9.2266 - loss: 6201.3931 - reconstruction_loss: 6192.1665 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8509 - loss: 3833.2998 - reconstruction_loss: 3828.449
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.7815 - loss: 3799.9246 - reconstruction_loss: 3795.1433 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5898 - loss: 3339.8955 - reconstruction_loss: 3336.305
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6075 - loss: 3326.5393 - reconstruction_loss: 3322.9319 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6851 - loss: 3029.9854 - reconstruction_loss: 3026.300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.7268 - loss: 3021.0242 - reconstruction_loss: 3017.2974 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4601 - loss: 2796.2324 - reconstruction_loss: 2792.772
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.4868 - loss: 2786.2522 - reconstruction_loss: 2782.7651 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4429 - loss: 2751.3352 - reconstruction_loss: 2747.892
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4418 - loss: 2744.8640 - reconstruction_loss: 2741.4221 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2436 - loss: 2712.7222 - reconstruction_loss: 2709.478
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.2616 - loss: 2711.6174 - reconstruction_loss: 2708.3560 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2564 - loss: 2596.6975 - reconstruction_loss: 2593.440
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.2759 - loss: 2592.0503 - reconstruction_loss: 2588.7744 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4384 - loss: 2758.6858 - reconstruction_loss: 2755.247
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4829 - loss: 2798.3660 - reconstruction_loss: 2794.8828 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.6624 - loss: 2948.1084 - reconstruction_loss: 2944.446
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6420 - loss: 2924.1047 - reconstruction_loss: 2920.4629 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2351 - loss: 2716.4458 - reconstruction_loss: 2713.210
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.2501 - loss: 2738.5122 - reconstruction_loss: 2735.2620 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4350 - loss: 2830.0813 - reconstruction_loss: 2826.646
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4174 - loss: 2838.8489 - reconstruction_loss: 2835.4314 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.3535 - loss: 2717.3015 - reconstruction_loss: 2713.947
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.3584 - loss: 2720.9224 - reconstruction_loss: 2717.5640 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4367 - loss: 2845.8774 - reconstruction_loss: 2842.440
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.4410 - loss: 2863.3225 - reconstruction_loss: 2859.8818 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.9645 - loss: 3019.6331 - reconstruction_loss: 3015.668
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.0539 - loss: 3074.9131 - reconstruction_loss: 3070.8589 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.7501 - loss: 3761.6011 - reconstruction_loss: 3756.851
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 5.3566 - loss: 3949.3262 - reconstruction_loss: 3943.9695 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.1702 - loss: 3560.1541 - reconstruction_loss: 3553.983
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 6.1688 - loss: 3561.5391 - reconstruction_loss: 3555.3706 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.0851 - loss: 3261.8574 - reconstruction_loss: 3256.772
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.0343 - loss: 3216.6711 - reconstruction_loss: 3211.6370 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.6870 - loss: 3065.7515 - reconstruction_loss: 3061.064
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6900 - loss: 3033.8760 - reconstruction_loss: 3029.1858 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8282 - loss: 2736.4199 - reconstruction_loss: 2731.591
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.8171 - loss: 2729.3772 - reconstruction_loss: 2724.5601 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0981 - loss: 2483.8513 - reconstruction_loss: 2479.752
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.0738 - loss: 2487.5037 - reconstruction_loss: 2483.4299 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8469 - loss: 2533.8926 - reconstruction_loss: 2530.045
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.8612 - loss: 2538.0894 - reconstruction_loss: 2534.2280 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8316 - loss: 2675.0576 - reconstruction_loss: 2671.226
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.8873 - loss: 2683.4739 - reconstruction_loss: 2679.5867 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.9325 - loss: 3261.0332 - reconstruction_loss: 3257.101
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.1273 - loss: 3248.1199 - reconstruction_loss: 3243.9927 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.6380 - loss: 2949.7581 - reconstruction_loss: 2945.120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.6903 - loss: 2923.8137 - reconstruction_loss: 2919.1233 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.4177 - loss: 3124.8442 - reconstruction_loss: 3119.426
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 5.4103 - loss: 3062.6733 - reconstruction_loss: 3057.2632 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.4458 - loss: 2420.4297 - reconstruction_loss: 2415.983
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - kl_loss: 4.4317 - loss: 2398.8672 - reconstruction_loss: 2394.4353 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8408 - loss: 2453.9944 - reconstruction_loss: 2450.153
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 3.8898 - loss: 2460.1958 - reconstruction_loss: 2456.3062 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.9746 - loss: 2564.3103 - reconstruction_loss: 2560.335
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.0374 - loss: 2554.9976 - reconstruction_loss: 2550.9602 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4640 - loss: 2493.6558 - reconstruction_loss: 2490.191
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.5335 - loss: 2480.8101 - reconstruction_loss: 2477.2766 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5734 - loss: 2425.0928 - reconstruction_loss: 2421.519
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.6322 - loss: 2405.7771 - reconstruction_loss: 2402.1448 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.3100 - loss: 2271.4521 - reconstruction_loss: 2268.142
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.3384 - loss: 2267.5352 - reconstruction_loss: 2264.1968 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5300 - loss: 2509.7495 - reconstruction_loss: 2506.219
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.6115 - loss: 2483.3528 - reconstruction_loss: 2479.7412 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.9416 - loss: 2338.6931 - reconstruction_loss: 2334.751
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.9781 - loss: 2312.5166 - reconstruction_loss: 2308.5386 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.3333 - loss: 2348.5693 - reconstruction_loss: 2345.236
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.4223 - loss: 2332.2312 - reconstruction_loss: 2328.8088 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4256 - loss: 2286.7761 - reconstruction_loss: 2283.350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.5092 - loss: 2257.3936 - reconstruction_loss: 2253.8845 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2934 - loss: 2173.2258 - reconstruction_loss: 2169.932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.3774 - loss: 2151.2590 - reconstruction_loss: 2147.8816 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.2043 - loss: 2120.5962 - reconstruction_loss: 2117.391
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.3292 - loss: 2093.6890 - reconstruction_loss: 2090.3599 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.3260 - loss: 2087.1716 - reconstruction_loss: 2083.845
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.4285 - loss: 2077.2524 - reconstruction_loss: 2073.8240 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.7913 - loss: 2272.2476 - reconstruction_loss: 2268.456
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.8743 - loss: 2243.1621 - reconstruction_loss: 2239.2876 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3077 - loss: 2721.5181 - reconstruction_loss: 2717.210
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.3598 - loss: 2636.0776 - reconstruction_loss: 2631.7178 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1337 - loss: 2847.9814 - reconstruction_loss: 2842.847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.1076 - loss: 2743.6277 - reconstruction_loss: 2738.5203 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1215 - loss: 2457.9932 - reconstruction_loss: 2452.871
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.1821 - loss: 2441.9910 - reconstruction_loss: 2436.8091 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.0721 - loss: 2406.4111 - reconstruction_loss: 2401.338
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.1295 - loss: 2401.3560 - reconstruction_loss: 2396.2266 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1289 - loss: 2418.9697 - reconstruction_loss: 2413.840
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.1605 - loss: 2411.4568 - reconstruction_loss: 2406.2961 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3856 - loss: 2381.3799 - reconstruction_loss: 2376.994
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.5273 - loss: 2358.2800 - reconstruction_loss: 2353.7524 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5690 - loss: 2793.1560 - reconstruction_loss: 2788.586
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.7977 - loss: 2781.2900 - reconstruction_loss: 2776.4922 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.7050 - loss: 2560.4507 - reconstruction_loss: 2555.745
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9789 - loss: 2585.5264 - reconstruction_loss: 2580.5476 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.9890 - loss: 4400.4932 - reconstruction_loss: 4393.503
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.9447 - loss: 4279.9062 - reconstruction_loss: 4272.9614 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 19.8743 - loss: 2599.1411 - reconstruction_loss: 2579.266
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 20.4175 - loss: 2567.2832 - reconstruction_loss: 2546.8657 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.7536 - loss: 2414.1138 - reconstruction_loss: 2409.360
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.7928 - loss: 2408.4573 - reconstruction_loss: 2403.6646 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.2708 - loss: 2239.2905 - reconstruction_loss: 2234.020
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.2844 - loss: 2228.2651 - reconstruction_loss: 2222.9810 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8136 - loss: 2393.5122 - reconstruction_loss: 2389.698
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 3.9845 - loss: 2333.4280 - reconstruction_loss: 2329.4434 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0781 - loss: 2307.4792 - reconstruction_loss: 2303.401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.1613 - loss: 2289.8440 - reconstruction_loss: 2285.6829 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.8041 - loss: 2150.0820 - reconstruction_loss: 2144.278
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 6.2356 - loss: 2122.1233 - reconstruction_loss: 2115.8877 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5640 - loss: 2298.3455 - reconstruction_loss: 2293.781
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.5831 - loss: 2233.5796 - reconstruction_loss: 2228.9966 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0891 - loss: 2278.2744 - reconstruction_loss: 2274.185
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.1695 - loss: 2189.8892 - reconstruction_loss: 2185.7195 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.1570 - loss: 1805.6859 - reconstruction_loss: 1801.528
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.2053 - loss: 1789.7493 - reconstruction_loss: 1785.5439 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8715 - loss: 1790.4180 - reconstruction_loss: 1786.546
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.0212 - loss: 1770.4669 - reconstruction_loss: 1766.4457 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.7454 - loss: 1829.3337 - reconstruction_loss: 1825.588
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.9216 - loss: 1800.0851 - reconstruction_loss: 1796.1633 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5762 - loss: 1979.7473 - reconstruction_loss: 1976.171
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.7444 - loss: 1943.8336 - reconstruction_loss: 1940.0892 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.5829 - loss: 1872.6064 - reconstruction_loss: 1869.023
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.6693 - loss: 1860.8254 - reconstruction_loss: 1857.1562 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.4945 - loss: 1882.9043 - reconstruction_loss: 1879.409
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.7218 - loss: 1855.4441 - reconstruction_loss: 1851.7224 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9497 - loss: 2814.2471 - reconstruction_loss: 2809.297
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9644 - loss: 2677.1111 - reconstruction_loss: 2672.1465 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8580 - loss: 2336.6799 - reconstruction_loss: 2331.822
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9231 - loss: 2268.7239 - reconstruction_loss: 2263.8005 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8119 - loss: 2153.1917 - reconstruction_loss: 2148.379
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.8689 - loss: 2146.7434 - reconstruction_loss: 2141.8745 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3082 - loss: 2214.7192 - reconstruction_loss: 2210.411
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.5938 - loss: 2192.3057 - reconstruction_loss: 2187.7119 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0531 - loss: 2055.9707 - reconstruction_loss: 2051.917
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.2573 - loss: 2022.0886 - reconstruction_loss: 2017.8313 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.6852 - loss: 2074.4307 - reconstruction_loss: 2069.745
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.8040 - loss: 1998.8406 - reconstruction_loss: 1994.0365 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8783 - loss: 1953.9421 - reconstruction_loss: 1949.063
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9648 - loss: 1877.8171 - reconstruction_loss: 1872.8523 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.4702 - loss: 1534.7587 - reconstruction_loss: 1530.288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6653 - loss: 1501.3267 - reconstruction_loss: 1496.6613 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0386 - loss: 1724.8015 - reconstruction_loss: 1720.762
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.3105 - loss: 1695.6542 - reconstruction_loss: 1691.3439 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.1117 - loss: 1646.3799 - reconstruction_loss: 1642.268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.2090 - loss: 1631.9252 - reconstruction_loss: 1627.7162 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.8877 - loss: 1561.6753 - reconstruction_loss: 1557.787
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.1459 - loss: 1544.0775 - reconstruction_loss: 1539.9316 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.2075 - loss: 1817.4105 - reconstruction_loss: 1812.203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.3232 - loss: 1748.0762 - reconstruction_loss: 1742.7532 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5507 - loss: 1539.1641 - reconstruction_loss: 1534.613
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6404 - loss: 1524.3861 - reconstruction_loss: 1519.7456 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3858 - loss: 1548.9352 - reconstruction_loss: 1544.549
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6336 - loss: 1527.2703 - reconstruction_loss: 1522.6367 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0036 - loss: 1569.6465 - reconstruction_loss: 1565.642
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.2307 - loss: 1537.2509 - reconstruction_loss: 1533.0203 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.7024 - loss: 1458.6267 - reconstruction_loss: 1454.924
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 3.9710 - loss: 1426.5333 - reconstruction_loss: 1422.5624 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0445 - loss: 1402.5104 - reconstruction_loss: 1398.465
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.2687 - loss: 1371.3687 - reconstruction_loss: 1367.1000 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.2402 - loss: 1419.2761 - reconstruction_loss: 1415.035
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.4563 - loss: 1376.2235 - reconstruction_loss: 1371.7671 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5104 - loss: 1356.1385 - reconstruction_loss: 1351.628
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 4.6828 - loss: 1326.8522 - reconstruction_loss: 1322.1694 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.4223 - loss: 1264.0833 - reconstruction_loss: 1259.660
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 4.6250 - loss: 1247.8490 - reconstruction_loss: 1243.2240 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.3466 - loss: 1345.6499 - reconstruction_loss: 1341.303
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6021 - loss: 1327.1194 - reconstruction_loss: 1322.5172 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 3.9668 - loss: 1511.2292 - reconstruction_loss: 1507.262
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.2892 - loss: 1469.3108 - reconstruction_loss: 1465.0216 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.0915 - loss: 1269.1974 - reconstruction_loss: 1265.105
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.3307 - loss: 1255.3538 - reconstruction_loss: 1251.0232 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.4105 - loss: 1333.9888 - reconstruction_loss: 1329.578
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 4.6160 - loss: 1315.1251 - reconstruction_loss: 1310.5092 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.2046 - loss: 1695.6995 - reconstruction_loss: 1690.494
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.3577 - loss: 1619.2291 - reconstruction_loss: 1613.8715 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.2165 - loss: 1387.9973 - reconstruction_loss: 1382.780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.3126 - loss: 1380.7195 - reconstruction_loss: 1375.4069 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5701 - loss: 1538.3359 - reconstruction_loss: 1533.766
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.7794 - loss: 1523.8975 - reconstruction_loss: 1519.1180 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.2254 - loss: 1850.9609 - reconstruction_loss: 1846.735
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.6443 - loss: 1810.3103 - reconstruction_loss: 1805.6660 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.6949 - loss: 1747.8890 - reconstruction_loss: 1743.194
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.0080 - loss: 1697.2855 - reconstruction_loss: 1692.2776 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1354 - loss: 1754.7024 - reconstruction_loss: 1749.567
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 5.2210 - loss: 1734.4236 - reconstruction_loss: 1729.2028 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8657 - loss: 1519.9532 - reconstruction_loss: 1515.087
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.0897 - loss: 1479.9579 - reconstruction_loss: 1474.8682 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.0010 - loss: 1491.6616 - reconstruction_loss: 1486.660
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.3125 - loss: 1498.2360 - reconstruction_loss: 1492.9233 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.6624 - loss: 2758.5840 - reconstruction_loss: 2752.921
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.1243 - loss: 2730.5615 - reconstruction_loss: 2724.4375 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.4940 - loss: 3662.5242 - reconstruction_loss: 3656.030
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.5873 - loss: 3607.6511 - reconstruction_loss: 3601.0640 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.4755 - loss: 2274.0400 - reconstruction_loss: 2267.564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.6034 - loss: 2197.5771 - reconstruction_loss: 2190.9736 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1159 - loss: 2014.5558 - reconstruction_loss: 2009.440
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.2912 - loss: 1968.2332 - reconstruction_loss: 1962.9420 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 6.0434 - loss: 1981.3812 - reconstruction_loss: 1975.337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 6.1460 - loss: 1902.5643 - reconstruction_loss: 1896.4185 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 5.1728 - loss: 1499.9313 - reconstruction_loss: 1494.758
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.4043 - loss: 1461.1611 - reconstruction_loss: 1455.7567 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9436 - loss: 1390.4257 - reconstruction_loss: 1385.482
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.1723 - loss: 1362.0903 - reconstruction_loss: 1356.9182 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.9156 - loss: 1349.4518 - reconstruction_loss: 1344.536
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 5.1450 - loss: 1328.8802 - reconstruction_loss: 1323.7351 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.5932 - loss: 1499.5924 - reconstruction_loss: 1494.999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 4.9464 - loss: 1448.4604 - reconstruction_loss: 1443.5140 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 4.8155 - loss: 1272.4728 - reconstruction_loss: 1267.657
# ...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 17.6779 - loss: 819.0988 - reconstruction_loss: 801.4208 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 408/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.1053 - loss: 902.1206 - reconstruction_loss: 886.015
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 16.0602 - loss: 895.6733 - reconstruction_loss: 879.6131 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 409/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.1281 - loss: 935.6296 - reconstruction_loss: 919.501
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.7247 - loss: 914.1086 - reconstruction_loss: 898.3839 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 410/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 19.5831 - loss: 926.3000 - reconstruction_loss: 906.716
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 19.0021 - loss: 904.1631 - reconstruction_loss: 885.1609 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 411/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.8560 - loss: 945.4590 - reconstruction_loss: 927.603
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 17.8504 - loss: 938.7955 - reconstruction_loss: 920.9451 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 412/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.0920 - loss: 873.0220 - reconstruction_loss: 856.930
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.9127 - loss: 861.8527 - reconstruction_loss: 845.9400 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 413/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.0637 - loss: 864.3757 - reconstruction_loss: 848.312
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.8293 - loss: 850.8923 - reconstruction_loss: 835.0631 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 414/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.3108 - loss: 778.5166 - reconstruction_loss: 761.205
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.9988 - loss: 765.7259 - reconstruction_loss: 748.7271 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 415/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.1350 - loss: 750.0659 - reconstruction_loss: 732.931
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 17.1173 - loss: 744.3055 - reconstruction_loss: 727.1883 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 416/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.1346 - loss: 779.3903 - reconstruction_loss: 763.255
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 15.9936 - loss: 766.1439 - reconstruction_loss: 750.1503 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 417/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.3971 - loss: 755.7556 - reconstruction_loss: 739.358
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 16.0650 - loss: 743.0111 - reconstruction_loss: 726.9462 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 418/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.4755 - loss: 744.2958 - reconstruction_loss: 725.820
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 18.2449 - loss: 732.0865 - reconstruction_loss: 713.8416 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 419/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.8976 - loss: 821.7176 - reconstruction_loss: 805.820
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 15.9862 - loss: 799.4179 - reconstruction_loss: 783.4318 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 420/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.2673 - loss: 756.4330 - reconstruction_loss: 739.165
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 17.0100 - loss: 745.8090 - reconstruction_loss: 728.7989 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 421/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.0781 - loss: 842.8378 - reconstruction_loss: 825.759
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.8942 - loss: 837.9037 - reconstruction_loss: 821.0095 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 422/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.1605 - loss: 848.0539 - reconstruction_loss: 829.893
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 18.1021 - loss: 836.6904 - reconstruction_loss: 818.5883 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 423/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.4848 - loss: 1021.1457 - reconstruction_loss: 1005.660
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.6258 - loss: 995.6786 - reconstruction_loss: 980.0529 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 424/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.6373 - loss: 1070.0250 - reconstruction_loss: 1051.387
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 17.9789 - loss: 1043.5839 - reconstruction_loss: 1025.6052 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 425/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.3724 - loss: 818.7746 - reconstruction_loss: 801.402
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 16.9386 - loss: 806.7018 - reconstruction_loss: 789.7632 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 426/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.4326 - loss: 851.5870 - reconstruction_loss: 835.154
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.4621 - loss: 834.1865 - reconstruction_loss: 817.7244 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 427/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.9438 - loss: 802.6112 - reconstruction_loss: 786.667
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.7295 - loss: 784.4206 - reconstruction_loss: 768.6911 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 428/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.9401 - loss: 769.4051 - reconstruction_loss: 751.464
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 17.7706 - loss: 762.3098 - reconstruction_loss: 744.5391 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 429/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.0567 - loss: 718.5510 - reconstruction_loss: 701.494
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 16.9264 - loss: 707.6446 - reconstruction_loss: 690.7182 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 430/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 14.5048 - loss: 773.3116 - reconstruction_loss: 758.806
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 14.5025 - loss: 757.5808 - reconstruction_loss: 743.0784 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 431/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.4054 - loss: 720.1253 - reconstruction_loss: 701.719
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 18.2382 - loss: 714.3166 - reconstruction_loss: 696.0784 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 432/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.7828 - loss: 684.1492 - reconstruction_loss: 666.366
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 17.4868 - loss: 668.1638 - reconstruction_loss: 650.6770 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 433/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 14.9577 - loss: 739.2721 - reconstruction_loss: 724.314
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 14.9535 - loss: 724.9078 - reconstruction_loss: 709.9543 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 434/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.6650 - loss: 665.8195 - reconstruction_loss: 649.154
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.5548 - loss: 660.2826 - reconstruction_loss: 643.7278 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 435/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.9427 - loss: 699.5132 - reconstruction_loss: 680.570
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 18.5275 - loss: 681.4707 - reconstruction_loss: 662.9432 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 436/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.6899 - loss: 719.5698 - reconstruction_loss: 702.879
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.6134 - loss: 701.7022 - reconstruction_loss: 685.0888 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 437/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.4942 - loss: 692.3406 - reconstruction_loss: 676.846
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 15.3446 - loss: 674.7887 - reconstruction_loss: 659.4441 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 438/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.2418 - loss: 726.5350 - reconstruction_loss: 708.293
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 18.0881 - loss: 721.0070 - reconstruction_loss: 702.9189 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 439/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.2981 - loss: 710.6608 - reconstruction_loss: 692.362
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 18.0815 - loss: 696.0463 - reconstruction_loss: 677.9648 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 440/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 14.8587 - loss: 775.5435 - reconstruction_loss: 760.684
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 14.8920 - loss: 754.8657 - reconstruction_loss: 739.9737 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 441/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.0887 - loss: 735.1270 - reconstruction_loss: 718.038
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.7983 - loss: 720.7997 - reconstruction_loss: 704.0014 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 442/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 19.3155 - loss: 697.9176 - reconstruction_loss: 678.602
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 18.9772 - loss: 680.1092 - reconstruction_loss: 661.1320 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 443/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.3931 - loss: 719.5600 - reconstruction_loss: 703.166
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 16.3492 - loss: 699.1620 - reconstruction_loss: 682.8128 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 444/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.8828 - loss: 689.4789 - reconstruction_loss: 673.596
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 15.6167 - loss: 671.0051 - reconstruction_loss: 655.3884 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 445/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.6576 - loss: 660.6691 - reconstruction_loss: 642.011
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 18.2683 - loss: 643.0372 - reconstruction_loss: 624.7689 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 446/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.5150 - loss: 653.7117 - reconstruction_loss: 636.196
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - kl_loss: 17.4019 - loss: 641.9511 - reconstruction_loss: 624.5492 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 447/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 15.5516 - loss: 647.3192 - reconstruction_loss: 631.767
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 15.4392 - loss: 635.3071 - reconstruction_loss: 619.8679 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 448/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 17.5201 - loss: 637.9821 - reconstruction_loss: 620.462
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - kl_loss: 17.2399 - loss: 625.4379 - reconstruction_loss: 608.1981 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 449/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 18.1964 - loss: 629.2965 - reconstruction_loss: 611.100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - kl_loss: 17.9873 - loss: 613.3379 - reconstruction_loss: 595.3506 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# Epoch 450/450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/stepep - kl_loss: 16.1807 - loss: 642.2659 - reconstruction_loss: 626.085
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - kl_loss: 16.0661 - loss: 624.4178 - reconstruction_loss: 608.3517 - val_kl_loss: 0.0000e+00 - val_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>MVD_Clocks</td><td>▃▂▁▁▁▃▄▅▄▄▄▄▄▆▆▄▅▅▅▅▅▆▅▇▅▅▆▆▆▆▅▆▅▆▇█▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>kl_loss</td><td>▂█▁▁▁▁▁▁▁▁▁▁▂▁▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>loss</td><td>█▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>reconstruction_loss</td><td>█▆▅▅▄▄▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_kl_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_reconstruction_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>MVD_Clocks</td><td>267.9386</td></tr><tr><td>epoch</td><td>449</td></tr><tr><td>kl_loss</td><td>15.55548</td></tr><tr><td>loss</td><td>555.64618</td></tr><tr><td>reconstruction_loss</td><td>540.0907</td></tr><tr><td>val_kl_loss</td><td>0</td></tr><tr><td>val_loss</td><td>0</td></tr><tr><td>val_reconstruction_loss</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">VAE_Clock_Arturo</strong> at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/nt62wt8l' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/nt62wt8l</a><br> View project at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20250322_022839-nt62wt8l/logs</code>
# 0

# %%
# Ejemplo de evaluación posterior con la métrica MVD en test
run_eval = wandb.init(project="VAE + DAE", name="Evaluation_MVD", reinit=True)

def evaluate_mvd(decoder, real_data, latent_dim, label_prefix):
    n_samples = len(real_data)
    z_samples = np.random.normal(size=(n_samples, latent_dim))
    gen_images = decoder.predict(z_samples)
    mvd_val = calc_mvd(real_data, gen_images)
    print(f"{label_prefix} VAE - MVD: {mvd_val:.2f}")
    wandb.log({f"MVD_{label_prefix}_test": mvd_val})

# Cargamos los modelos (si fuera un nuevo entorno, harías load_model con custom_objects)
# vae_bottle_loaded = tf.keras.models.load_model("vae_bottle_model_Arturo.keras", custom_objects={"calc_mvd": calc_mvd, "VAE": VAE})
# O en el mismo notebook simplemente reusas "decoder_bottle".

# Evaluación en test
evaluate_mvd(decoder_bottle, X_test_botellas, LATENT_DIM, "Bottle")
evaluate_mvd(decoder_clock, X_test_relojes, LATENT_DIM, "Clock")

wandb.finish()
# Out:
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250322_023323-2yii5pxw</code>
# Syncing run <strong><a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/2yii5pxw' target="_blank">Evaluation_MVD</a></strong> to <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE</a>
#  View run at <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/2yii5pxw' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/2yii5pxw</a>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Bottle VAE - MVD: 286.10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Clock VAE - MVD: 252.24
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>MVD_Bottle_test</td><td>▁</td></tr><tr><td>MVD_Clock_test</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>MVD_Bottle_test</td><td>286.10321</td></tr><tr><td>MVD_Clock_test</td><td>252.2417</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Evaluation_MVD</strong> at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/2yii5pxw' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/2yii5pxw</a><br> View project at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250322_023323-2yii5pxw/logs</code>

# %%
# Visualización de algunas imágenes generadas
def display_generated_images(gen_images, title):
    plt.figure(figsize=(10, 5))
    n = min(5, gen_images.shape[0])
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(gen_images[i])
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# Generar imágenes con el decoder de botellas
z_samples_bottle = np.random.normal(size=(5, LATENT_DIM))
gen_images_bottle = decoder_bottle.predict(z_samples_bottle)
display_generated_images(gen_images_bottle, "Generated Images - Bottle VAE")

# Generar imágenes con el decoder de relojes
z_samples_clock = np.random.normal(size=(5, LATENT_DIM))
gen_images_clock = decoder_clock.predict(z_samples_clock)
display_generated_images(gen_images_clock, "Generated Images - Clock VAE")

# Log en W&B
run_vis = wandb.init(project="VAE + DAE", name="Generated_Images", reinit=True)
wandb.log({
    "Generated_Images_Bottle": [wandb.Image(img) for img in gen_images_bottle[:5]],
    "Generated_Images_Clock": [wandb.Image(img) for img in gen_images_clock[:5]]
})
wandb.finish()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250322_023333-xk7to1jm</code>
# Syncing run <strong><a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/xk7to1jm' target="_blank">Generated_Images</a></strong> to <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE</a>
#  View run at <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/xk7to1jm' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/xk7to1jm</a>
#  View run <strong style="color:#cdcd00">Generated_Images</strong> at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/xk7to1jm' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE/runs/xk7to1jm</a><br> View project at: <a href='https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE' target="_blank">https://wandb.ai/diegomercadoc-iteso/VAE%20%2B%20DAE</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 10 other file(s)
# Find logs at: <code>./wandb/run-20250322_023333-xk7to1jm/logs</code>

# %%
from huggingface_hub import HfApi

api = HfApi()

# %%
# En entornos como  Colab, a veces no se configura un helper de credenciales de git.
# Normalmente esto no es un error fatal, sino un aviso de que podrías tener que re-autenticarte
# al subir cambios al Hub. Aun así, puedes usar tu token de forma explícita:

# !git config --global credential.helper store  # (Opcional) Para evitar el aviso en local

from huggingface_hub import HfApi

# Sustituye 'hf_...' con tu token personal de Hugging Face
my_token = "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"

api = HfApi()

# 1) Crea (o asegura la existencia de) tu repositorio en Hugging Face
api.create_repo(
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
    exist_ok=True,
    token=my_token
)

# 2) Sube tu archivo .keras al repositorio
api.upload_file(
    path_or_fileobj="/content/working/encoder_bottle_Arturo.keras",
    path_in_repo="encoder_bottle_Arturo.keras",
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
    token=my_token
)
# Out:
# encoder_bottle_Arturo.keras:   0%|          | 0.00/272M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Ju4nPa2009/VAE_DAE/commit/0b9827d87754ba19789026925262877594f276c4', commit_message='Upload encoder_bottle_Arturo.keras with huggingface_hub', commit_description='', oid='0b9827d87754ba19789026925262877594f276c4', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Ju4nPa2009/VAE_DAE', endpoint='https://huggingface.co', repo_type='model', repo_id='Ju4nPa2009/VAE_DAE'), pr_revision=None, pr_num=None)

# %%
from huggingface_hub import notebook_login, HfApi, create_repo

# 1) Iniciar sesión en Hugging Face (si no lo has hecho ya)
notebook_login()

# 2) Crear (o asegurar la existencia de) tu repositorio en Hugging Face
create_repo(repo_id="Ju4nPa2009/VAE_DAE", repo_type="model", exist_ok=True)

# 3) Instanciar la API de Hugging Face
api = HfApi()

# 4) Subir los archivos .keras al repositorio
api.upload_file(
    path_or_fileobj="/content/working/encoder_bottle_Arturo.keras",
    path_in_repo="encoder_bottle_Arturo.keras",
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
)
api.upload_file(
    path_or_fileobj="/content/working/decoder_bottle_Arturo.keras",
    path_in_repo="decoder_bottle_Arturo.keras",
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
)
api.upload_file(
    path_or_fileobj="/content/working/encoder_clock_Arturo.keras",
    path_in_repo="encoder_clock_Arturo.keras",
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
)
api.upload_file(
    path_or_fileobj="/content/working/decoder_clock_Arturo.keras",
    path_in_repo="decoder_clock_Arturo.keras",
    repo_id="Ju4nPa2009/VAE_DAE",
    repo_type="model",
)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# No files have been modified since last commit. Skipping to prevent empty commit.
# decoder_bottle_Arturo.keras:   0%|          | 0.00/71.3M [00:00<?, ?B/s]
# encoder_clock_Arturo.keras:   0%|          | 0.00/272M [00:00<?, ?B/s]
# decoder_clock_Arturo.keras:   0%|          | 0.00/71.3M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Ju4nPa2009/VAE_DAE/commit/b4b73d3be528ad8ea745b06cb4bbca91ad5002f0', commit_message='Upload decoder_clock_Arturo.keras with huggingface_hub', commit_description='', oid='b4b73d3be528ad8ea745b06cb4bbca91ad5002f0', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Ju4nPa2009/VAE_DAE', endpoint='https://huggingface.co', repo_type='model', repo_id='Ju4nPa2009/VAE_DAE'), pr_revision=None, pr_num=None)
